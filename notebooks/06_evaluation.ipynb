# %% [markdown]
# # Model Performance Evaluation
# Detailed evaluation of baseline and quantum configurations.

# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

sys.path.append(os.path.abspath('..'))
from src.evaluation.comparison import compare_classical_vs_quantum

# %% [markdown]
# ## 1. Classical vs. Quantum Comparison Matrix

# %%
predictions_dir = '../models'
class_names = ['glioma', 'meningioma', 'notumor', 'pituitary']

results, df_compare = compare_classical_vs_quantum(predictions_dir, class_names)
display(df_compare)

# %% [markdown]
# ## 2. Overall Metric Comparison Chart

# %%
fig_path = Path('../reports/figures/grouped_metric_comparison.png')
if fig_path.exists():
    img = plt.imread(str(fig_path))
    plt.figure(figsize=(12, 8))
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## 3. Confusion Matrices & ROC Curves

# %%
# Example visualization for Quantum B
fig_path = Path('../reports/figures/confusion_matrix_quantum_b_xgb.png')
if fig_path.exists():
    img = plt.imread(str(fig_path))
    plt.figure(figsize=(8, 6))
    plt.imshow(img)
    plt.axis('off')
    plt.show()
